# %%
import matplotlib.pyplot as plt

# %%
squares = [x**2 for x in range(1, 10)]
cubes = [x**3 for x in range(1, 10)]

# %%
plt.subplot(1, 2, 1)
plt.plot(squares)

plt.subplot(1, 2, 2)
plt.plot(cubes)

plt.tight_layout()
plt.show()
