# %%
from matplotlib import pyplot as plt

# %%
squares = [x**2 for x in range(1,1000)]
# print(squares)

# %%
# plt.plot(list(range(1,6)), squares)

# print(plt.style.available)
# plt.style.use("Solarize_Light2")
input_values = list(range(1,1000))

fig, ax = plt.subplots()
# ax.plot(squares)
# ax.plot(input_values, squares, linewidth=3)

ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

# ax.scatter(2, 4, s=200)
# ax.scatter(input_values, squares, s=100, c="red")
# ax.scatter(input_values, squares, s=100, color=(0.3, 0.8, 0.5, 1))
ax.scatter(input_values, squares, c=squares, cmap=plt.cm.Reds, s=10)

# ax.tick_params(axis="both", which="major", labelsize=14)

# %%
# plt.plot(input_values, squares, linestyle="")
plt.scatter(input_values, squares, c=squares, cmap="Reds", s=10)
plt.xlabel("Value", fontsize=14)
plt.ylabel("Square of Value", fontsize=14)
plt.title("Square Numbers", fontsize=24)
# Out:
# Text(0.5, 1.0, 'Square Numbers')
